# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import pprint
import csv
from datetime import datetime

# Import API key
from api_key import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# API Calls


url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

cities_data = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

count_cities = 0
count_sets = 0

for city in cities:
    count_cities = count_cities + 1
    try:
        # Build query URL and request results
        query_url = f"{url}appid={api_key}&q={city}&units={units}"

        # Get weather data
        weather_response = requests.get(query_url)
        weather_json = weather_response.json()

        # Save information

        cities_data.append(weather_json["name"])
        cloudiness.append(weather_json["clouds"]["all"])
        country.append(weather_json["sys"]["country"])
        date.append(weather_json["dt"])
        humidity.append(weather_json["main"]["humidity"])
        lat.append(weather_json["coord"]["lat"])
        lng.append(weather_json["coord"]["lon"])
        max_temp.append(weather_json["main"]["temp_max"])
        wind_speed.append(weather_json["wind"]["speed"])

        print(f"Request {count_cities} of {len(cities)}, Saving information for {city}")
    except:
        print(f"Request {count_cities} of {len(cities)}, {city} not found. Skipping...")
        pass
# Out:
# Request 1 of 590, Saving information for puerto ayora
# Request 2 of 590, Saving information for jamestown
# Request 3 of 590, Saving information for butaritari
# Request 4 of 590, Saving information for padang
# Request 5 of 590, Saving information for vanimo
# Request 6 of 590, Saving information for ribeira grande
# Request 7 of 590, Saving information for hobart
# Request 8 of 590, Saving information for east london
# Request 9 of 590, taolanaro not found. Skipping...
# Request 10 of 590, Saving information for isangel
# Request 11 of 590, Saving information for ola
# Request 12 of 590, Saving information for vardo
# Request 13 of 590, Saving information for leningradskiy
# Request 14 of 590, Saving information for pevek
# Request 15 of 590, Saving information for shubarshi
# Request 16 of 590, Saving information for nome
# Request 17 of 590, kota bahru not found. Skipping...
# Request 18 of 590, Saving information for northam
# Request 19 of 590, Saving information for barrow
# Request 20 of 590, Saving information for honghu
# Request 21 of 590, Saving information for termiz
# Request 22 of 590, Saving information for airai
# Request 23 of 590, Saving information for saskylakh
# Request 24 of 590, Saving information for aquiraz
# Request 25 of 590, Saving information for mataura
# Request 26 of 590, Saving information for oranjemund
# Request 27 of 590, mys shmidta not found. Skipping...
# Request 28 of 590, Saving information for labuhan
# Request 29 of 590, Saving information for rikitea
# Request 30 of 590, Saving information for busselton
# Request 31 of 590, Saving information for cape town
# Request 32 of 590, Saving information for ushuaia
# Request 33 of 590, Saving information for albany
# Request 34 of 590, Saving information for belmonte
# Request 35 of 590, Saving information for pacocha
# Request 36 of 590, Saving information for sibolga
# Request 37 of 590, Saving information for albanel
# Request 38 of 590, Saving information for port hueneme
# Request 39 of 590, Saving information for hoquiam
# Request 40 of 590, illoqqortoormiut not found. Skipping...
# Request 41 of 590, Saving information for soe
# Request 42 of 590, Saving information for port lincoln
# Request 43 of 590, Saving information for creel
# Request 44 of 590, Saving information for hilo
# Request 45 of 590, Saving information for lubao
# Request 46 of 590, Saving information for wick
# Request 47 of 590, Saving information for nikolskoye
# Request 48 of 590, Saving information for kavieng
# Request 49 of 590, Saving information for hithadhoo
# Request 50 of 590, Saving information for portland
# Request 51 of 590, Saving information for los llanos de aridane
# Request 52 of 590, Saving information for sainte-anne-des-monts
# Request 53 of 590, Saving information for vaini
# Request 54 of 590, Saving information for port alfred
# Request 55 of 590, Saving information for severo-kurilsk
# Request 56 of 590, Saving information for pirapemas

    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lat": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
    }

# %%
line = 0
with open(output_data_file, 'w', newline='') as csvfile:
    weather_cities = csv.writer(csvfile, delimiter=',')
    weather_cities.writerow(
         ['City', 'Cloudiness', 'Country', 'Date',
          'Humidity', 'Lat',"Lat",
          'Max Temp',"Wind Speed"])
 
    for city in cities_data:
        weather_cities.writerow(
         [cities_data[line],cloudiness[line], country[line], date[line], humidity[line], lat[line], 
          lng[line], max_temp[line], wind_speed[line]])
        line = line + 1

# %%
cities_df = pd.DataFrame(cities_dict)
cities_df.head()
# Out:
#            City  Cloudiness Country        Date  Humidity     Lat  Max Temp  \
# 0  Puerto Ayora          20      EC  1575313189        54  -90.35     84.20
# 1     Jamestown          28      AU  1575313189        97  138.60     46.80
# 2    Butaritari          60      KI  1575313189        75  172.79     84.25
# 3        Padang          75      ID  1575313189       100  100.36     73.40
# 4        Vanimo          49      PG  1575313190        77  141.30     82.22
#
#    Wind Speed
# 0       20.80
# 1       10.85
# 2       11.16
# 3        6.93
# 4        3.62

# %%
cities_df.count()
# Out:
# City          528
# Cloudiness    528
# Country       528
# Date          528
# Humidity      528
# Lat           528
# Max Temp      528
# Wind Speed    528
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
x_axis = cities_df["Lat"]

date= datetime.fromtimestamp(int(str(cities_df["Date"][0]))).strftime('%Y/%m/%d')

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots(figsize=(15, 10))


for x in cities_df["City"]:
    ax.scatter(x_axis, cities_df["Max Temp"], marker="o", s=100, edgecolors='black', c="blue", linewidths=2)

ax.set_title('City Latitude x Max Temperature ({})'.format(date), fontweight = "bold", fontsize = 15)
ax.set_xlim(-200, 200)
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
plt.tight_layout()
ax.grid()
plt.savefig("output_data/maxtemp.png", dpi=fig.dpi)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 10))


for x in cities_df["City"]:
    ax.scatter(x_axis, cities_df["Humidity"], marker="o", s=100, edgecolors='black', c="red", linewidths=2)

ax.set_title('City Latitude x Humidity ({})'.format(date), fontweight = "bold", fontsize = 15)
ax.set_xlim(-200, 200)
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
plt.tight_layout()
ax.grid()
plt.savefig("output_data/humidity.png", dpi=fig.dpi)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 10))


for x in cities_df["City"]:
    ax.scatter(x_axis, cities_df["Cloudiness"], marker="o", s=100, edgecolors='blue', c="white", linewidths=2)

ax.set_title('City Latitude x Cloudiness ({})'.format(date), fontweight = "bold", fontsize = 15)
ax.set_xlim(-200, 200)
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
plt.tight_layout()
ax.grid()
plt.savefig("output_data/cloudiness.png", dpi=fig.dpi)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15, 10))

for x in cities_df["City"]:
    ax.scatter(x_axis, cities_df["Wind Speed"], marker="o", s=100, edgecolors='black', c="green", linewidths=2)


ax.set_title('City Latitude x Wind Speed ({})'.format(date), fontweight = "bold", fontsize = 15)
ax.set_xlim(-200, 200)
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
plt.tight_layout()
ax.grid()
plt.savefig("output_data/wind_speed.png", dpi=fig.dpi)
plt.show()
